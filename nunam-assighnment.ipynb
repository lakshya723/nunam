# %%
import pandas as pd 
df = pd.read_csv("detail.csv")  
df
# Out:
#         Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                  1   Rest       1      1     1      0.0      3.5900
# 1                  2   Rest       1      1     1      0.0      3.5900
# 2                  3   Rest       1      1     1      0.0      3.5900
# 3                  4   Rest       1      1     1      0.0      3.5900
# 4                  5   Rest       1      1     1      0.0      3.5900
# ...              ...    ...     ...    ...   ...      ...         ...
# 416676        458630   Rest     108     21    83      0.0      3.5856
# 416677        458631   Rest     108     21    83      0.0      3.5853
# 416678        458632   Rest     108     21    83      0.0      3.5853
# 416679        458633   Rest     108     21    83      0.0      3.5856
# 416680        458634   Rest     108     21    83      0.0      3.5856
#
#         CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                 0.0          0.0               0:00:00.000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416681 entries, 0 to 416680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Record Index               416681 non-null  int64
#  1   Status                     416681 non-null  object
#  2   JumpTo                     416681 non-null  int64
#  3   Cycle                      416681 non-null  int64
#  4   Step                       416681 non-null  int64
#  5   Cur(mA)                    416681 non-null  float64
#  6   Voltage(V)                 416681 non-null  float64
#  7   CapaCity(mAh)              416681 non-null  float64
#  8   Energy(mWh)                416681 non-null  float64
#  9   Relative Time(h:min:s.ms)  416681 non-null  object
#  10  Absolute Time              416681 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 35.0+ MB

# %%
df['Absolute Time'] = pd.to_datetime(df['Absolute Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Absolute Time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-426decc6c5cf> in <module>
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=416681, step=1)

# %%
df = pd.read_csv("detail.csv", index_col="Absolute Time")
df
# Out:
#                      Record Index Status  JumpTo  Cycle  Step  Cur(mA)  \
# Absolute Time
# 10/10/2020 20:03:39             1   Rest       1      1     1      0.0
# 10/10/2020 20:03:40             2   Rest       1      1     1      0.0
# 10/10/2020 20:03:41             3   Rest       1      1     1      0.0
# 10/10/2020 20:03:42             4   Rest       1      1     1      0.0
# 10/10/2020 20:03:43             5   Rest       1      1     1      0.0
# ...                           ...    ...     ...    ...   ...      ...
# 10/16/2020 03:25:35        458630   Rest     108     21    83      0.0
# 10/16/2020 03:25:36        458631   Rest     108     21    83      0.0
# 10/16/2020 03:25:37        458632   Rest     108     21    83      0.0
# 10/16/2020 03:25:38        458633   Rest     108     21    83      0.0
# 10/16/2020 03:25:39        458634   Rest     108     21    83      0.0
#
#                      Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# Absolute Time
# ...

# %%
df.resample('T', label = 'right', closed='right').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-e2639ad379b2> in <module>
# ----> 1 df.resample('T', label = 'right', closed='right').sum()
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# D:\anaconda\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# D:\anaconda\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# ...

# %%
import pandas as pd 
df = pd.read_csv("detailVol.csv")
df
# Out:
#         Record ID Step Name Relative Time(h:min:s.ms)             Realtime  \
# 0               1      Rest               0:00:00.000  10/10/2020 20:03:39
# 1               2      Rest               0:00:01.000  10/10/2020 20:03:40
# 2               3      Rest               0:00:02.000  10/10/2020 20:03:41
# 3               4      Rest               0:00:03.000  10/10/2020 20:03:42
# 4               5      Rest               0:00:04.000  10/10/2020 20:03:43
# ...           ...       ...                       ...                  ...
# 416676     458630      Rest               0:09:56.000  10/16/2020 03:25:35
# 416677     458631      Rest               0:09:57.000  10/16/2020 03:25:36
# 416678     458632      Rest               0:09:58.000  10/16/2020 03:25:37
# 416679     458633      Rest               0:09:59.000  10/16/2020 03:25:38
# 416680     458634      Rest               0:10:00.000  10/16/2020 03:25:39
#
#         Auxiliary channel TU1 U(V)  Gap of Voltage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416681 entries, 0 to 416680
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Record ID                   416681 non-null  int64
#  1   Step Name                   416681 non-null  object
#  2   Relative Time(h:min:s.ms)   416681 non-null  object
#  3   Realtime                    416681 non-null  object
#  4   Auxiliary channel TU1 U(V)  416681 non-null  float64
#  5   Gap of Voltage              416681 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 19.1+ MB

# %%
df = pd.read_csv("detailVol.csv", index_col="Realtime")
df
# Out:
#                      Record ID Step Name Relative Time(h:min:s.ms)  \
# Realtime
# 10/10/2020 20:03:39          1      Rest               0:00:00.000
# 10/10/2020 20:03:40          2      Rest               0:00:01.000
# 10/10/2020 20:03:41          3      Rest               0:00:02.000
# 10/10/2020 20:03:42          4      Rest               0:00:03.000
# 10/10/2020 20:03:43          5      Rest               0:00:04.000
# ...                        ...       ...                       ...
# 10/16/2020 03:25:35     458630      Rest               0:09:56.000
# 10/16/2020 03:25:36     458631      Rest               0:09:57.000
# 10/16/2020 03:25:37     458632      Rest               0:09:58.000
# 10/16/2020 03:25:38     458633      Rest               0:09:59.000
# 10/16/2020 03:25:39     458634      Rest               0:10:00.000
#
#                      Auxiliary channel TU1 U(V)  Gap of Voltage
# Realtime
# 10/10/2020 20:03:39                     -0.0013             0.0
# ...

# %%
df['Realtime'] = pd.to_datetime(df['Realtime'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Realtime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-338849e5aa79> in <module>
# ...

# %%
df.resample('T', label = 'right', closed='right').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-e2639ad379b2> in <module>
# ----> 1 df.resample('T', label = 'right', closed='right').sum()
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# D:\anaconda\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# D:\anaconda\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# ...

# %%
import pandas as pd 
df = pd.read_csv("detailTemp.csv")
df
# Out:
#         Record ID Step Name Relative Time(h:min:s.ms)             Realtime  \
# 0               1      Rest               0:00:00.000  10/10/2020 20:03:39
# 1               2      Rest               0:00:01.000  10/10/2020 20:03:40
# 2               3      Rest               0:00:02.000  10/10/2020 20:03:41
# 3               4      Rest               0:00:03.000  10/10/2020 20:03:42
# 4               5      Rest               0:00:04.000  10/10/2020 20:03:43
# ...           ...       ...                       ...                  ...
# 416676     458630      Rest               0:09:56.000  10/16/2020 03:25:35
# 416677     458631      Rest               0:09:57.000  10/16/2020 03:25:36
# 416678     458632      Rest               0:09:58.000  10/16/2020 03:25:37
# 416679     458633      Rest               0:09:59.000  10/16/2020 03:25:38
# 416680     458634      Rest               0:10:00.000  10/16/2020 03:25:39
#
#         Auxiliary channel TU1 T(°C)  Gap of Temperature
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416681 entries, 0 to 416680
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Record ID                    416681 non-null  int64
#  1   Step Name                    416681 non-null  object
#  2   Relative Time(h:min:s.ms)    416681 non-null  object
#  3   Realtime                     416681 non-null  object
#  4   Auxiliary channel TU1 T(°C)  416681 non-null  float64
#  5   Gap of Temperature           416681 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 19.1+ MB
